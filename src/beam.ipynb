# %%
import apache_beam as beam
from apache_beam.io.jdbc import ReadFromJdbc

# %%
with beam.Pipeline() as pipeline:
    (
        pipeline
        | "Read PSQL table" >> ReadFromJdbc(
            table_name='mba_decision',
            driver_class_name='org.postgresql.Driver',
            jdbc_url='jdbc:postgresql://localhost:54320/postgres',
            username='postgres',
            password='password'
        )
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/apache_beam/typehints/schemas.py:553, in SchemaTranslation.named_tuple_from_schema(self, schema)
#     552 try:
# --> 553   field_py_type = self.typing_from_runner_api(field.type)
#     554   if isinstance(field_py_type, row_type.RowTypeConstraint):
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/typehints/schemas.py:475, in SchemaTranslation.typing_from_runner_api(self, fieldtype_proto)
#     474 base_type.nullable = False
# --> 475 base = self.typing_from_runner_api(base_type)
#     476 if base == Any:
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/typehints/schemas.py:538, in SchemaTranslation.typing_from_runner_api(self, fieldtype_proto)
#     537   else:
# --> 538     return LogicalType.from_runner_api(
#     539         fieldtype_proto.logical_type).language_type()
#     541 else:
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/typehints/schemas.py:786, in LogicalType.from_runner_api(cls, logical_type_proto)
#     785 if logical_type is None:
# --> 786   raise ValueError(
#     787       "No logical type registered for URN '%s'" % logical_type_proto.urn)
#     788 if not logical_type_proto.HasField(
#     789     "argument_type") or not logical_type_proto.HasField("argument"):
#     790   # logical type_proto without argument
#
# ValueError: No logical type registered for URN 'beam:logical_type:javasdk_bit:v1'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 with beam.Pipeline() as pipeline:
#       2     (
# ----> 3         pipeline
#       4         | "Read PSQL table" >> ReadFromJdbc(
#       5             table_name='mba_decision',
#       6             driver_class_name='org.postgresql.Driver',
#       7             jdbc_url='jdbc:postgresql://localhost:54320/postgres',
#       8             username='postgres',
#       9             password='password'
#      10         )
#      11     )
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/transforms/ptransform.py:1127, in _NamedPTransform.__ror__(self, pvalueish, _unused)
#    1126 def __ror__(self, pvalueish, _unused=None):
# -> 1127   return self.transform.__ror__(pvalueish, self.label)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/transforms/ptransform.py:622, in PTransform.__ror__(self, left, label)
#     620 pvalueish = _SetInputPValues().visit(pvalueish, replacements)
#     621 self.pipeline = p
# --> 622 result = p.apply(self, pvalueish, label)
#     623 if deferred:
#     624   return result
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/pipeline.py:692, in Pipeline.apply(self, transform, pvalueish, label)
#     690 old_label, transform.label = transform.label, label
#     691 try:
# --> 692   return self.apply(transform, pvalueish)
#     693 finally:
#     694   transform.label = old_label
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/pipeline.py:754, in Pipeline.apply(self, transform, pvalueish, label)
#     751 if type_options.pipeline_type_check:
#     752   transform.type_check_inputs(pvalueish)
# --> 754 pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     756 if type_options is not None and type_options.pipeline_type_check:
#     757   transform.type_check_outputs(pvalueish_result)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/runners/runner.py:191, in PipelineRunner.apply(self, transform, input, options)
#     185 def apply(
#     186     self,
#     187     transform: 'PTransform',
#     188     input: Optional['pvalue.PValue'],
#     189     options: PipelineOptions):
#     190   # TODO(robertwb): Remove indirection once internal references are fixed.
# --> 191   return self.apply_PTransform(transform, input, options)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/runners/runner.py:195, in PipelineRunner.apply_PTransform(self, transform, input, options)
#     193 def apply_PTransform(self, transform, input, options):
#     194   # TODO(robertwb): Remove indirection once internal references are fixed.
# --> 195   return transform.expand(input)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/transforms/external.py:771, in ExternalTransform.expand(self, pvalueish)
#     768   pcoll.tag = tag
#     769   return pcoll
# --> 771 self._outputs = {
#     772     tag: fix_output(result_context.pcollections.get_by_id(pcoll_id), tag)
#     773     for tag,
#     774     pcoll_id in self._expanded_transform.outputs.items()
#     775 }
#     777 return self._output_to_pvalueish(self._outputs)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/transforms/external.py:772, in <dictcomp>(.0)
#     768   pcoll.tag = tag
#     769   return pcoll
#     771 self._outputs = {
# --> 772     tag: fix_output(result_context.pcollections.get_by_id(pcoll_id), tag)
#     773     for tag,
#     774     pcoll_id in self._expanded_transform.outputs.items()
#     775 }
#     777 return self._output_to_pvalueish(self._outputs)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/runners/pipeline_context.py:106, in _PipelineContextMap.get_by_id(self, id)
#     104 def get_by_id(self, id: str) -> PortableObjectT:
#     105   if id not in self._id_to_obj:
# --> 106     self._id_to_obj[id] = self._obj_type.from_runner_api(
#     107         self._id_to_proto[id], self._pipeline_context)
#     108   return self._id_to_obj[id]
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/pvalue.py:208, in PCollection.from_runner_api(proto, context)
#     196 @staticmethod
#     197 def from_runner_api(
#     198     proto: beam_runner_api_pb2.PCollection,
#    (...)
#     204   # Pipeline.from_runner_api(). This brief period is the only time that
#     205   # PCollection.pipeline is allowed to be None.
#     206   return PCollection(
#     207       None,  # type: ignore[arg-type]
# --> 208       element_type=context.element_type_from_coder_id(proto.coder_id),
#     209       windowing=context.windowing_strategies.get_by_id(
#     210           proto.windowing_strategy_id),
#     211       is_bounded=proto.is_bounded == beam_runner_api_pb2.IsBounded.BOUNDED)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/runners/pipeline_context.py:267, in PipelineContext.element_type_from_coder_id(self, coder_id)
#     264   return pickler.loads(coder_id)
#     265 else:
#     266   return native_type_compatibility.convert_to_beam_type(
# --> 267       self.coders[coder_id].to_type_hint())
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/runners/pipeline_context.py:158, in _PipelineContextMap.__getitem__(self, id)
#     157 def __getitem__(self, id: str) -> Any:
# --> 158   return self.get_by_id(id)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/runners/pipeline_context.py:106, in _PipelineContextMap.get_by_id(self, id)
#     104 def get_by_id(self, id: str) -> PortableObjectT:
#     105   if id not in self._id_to_obj:
# --> 106     self._id_to_obj[id] = self._obj_type.from_runner_api(
#     107         self._id_to_proto[id], self._pipeline_context)
#     108   return self._id_to_obj[id]
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/coders/coders.py:364, in Coder.from_runner_api(cls, coder_proto, context)
#     359 """Converts from an FunctionSpec to a Fn object.
#     360
#     361 Prefer registering a urn with its parameter type and constructor.
#     362 """
#     363 parameter_type, constructor = cls._known_urns[coder_proto.spec.urn]
# --> 364 return constructor(
#     365     proto_utils.parse_Bytes(coder_proto.spec.payload, parameter_type),
#     366     [context.coders.get_by_id(c) for c in coder_proto.component_coder_ids],
#     367     context)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/coders/row_coder.py:106, in RowCoder.from_runner_api_parameter(schema, components, unused_context)
#     103 @staticmethod
#     104 @Coder.register_urn(common_urns.coders.ROW.urn, schema_pb2.Schema)
#     105 def from_runner_api_parameter(schema, components, unused_context):
# --> 106   return RowCoder(schema)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/coders/row_coder.py:65, in RowCoder.__init__(self, schema, force_deterministic)
#      62 self.schema = schema
#      64 # Eagerly generate type hint to escalate any issues with the Schema proto
# ---> 65 self._type_hint = named_tuple_from_schema(self.schema)
#      67 # Use non-null coders because null values are represented separately
#      68 self.components = [
#      69     _nonnull_coder_from_type(field.type) for field in self.schema.fields
#      70 ]
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/typehints/schemas.py:596, in named_tuple_from_schema(schema, schema_registry)
#     593 def named_tuple_from_schema(
#     594     schema, schema_registry: SchemaTypeRegistry = SCHEMA_REGISTRY) -> type:
#     595   return SchemaTranslation(
# --> 596       schema_registry=schema_registry).named_tuple_from_schema(schema)
#
# File ~/.local/lib/python3.10/site-packages/apache_beam/typehints/schemas.py:557, in SchemaTranslation.named_tuple_from_schema(self, schema)
#     555     field_py_type = field_py_type.user_type
#     556 except ValueError as e:
# --> 557   raise ValueError(
#     558       "Failed to decode schema due to an issue with Field proto:\n\n"
#     559       f"{text_format.MessageToString(field)}") from e
#     561 descriptions[field.name] = field.description
#     562 subfields.append((field.name, field_py_type))
#
# ValueError: Failed to decode schema due to an issue with Field proto:
#
# name: "has_management_experience"
# type {
#   nullable: true
#   logical_type {
#     urn: "beam:logical_type:javasdk_bit:v1"
#     payload: "\202SNAPPY\000\000\000\000\001\000\000\000\001\000\000\002a\301\007\360@\254\355\000\005sr\000*org.apache.beam.sdk.io.jdbc.LogicalTypes$1%\263\224\246%\031\260\355\002\000\000xr\000?N9\000 schemas.l\t9Dtypes.PassThroughL\t\030\001Q\270\210\324\331\211\313P\033\263\002\000\004L\000\010argumentt\000\022Ljava/lang/Object;L\000\014a\r \001:\034t\000.Lorg/\t\266\000/\001\266\020/sdk/\r}\004/S\005\205\024$Field\0010\020;L\000\tf\021\rDq\000~\000\003L\000\nidentifier6s\000<String;xpt\000\000sr\0006n\346\000$AutoValue_\ts\000_\025sh9\304m\364S\243\227P\002\000\010L\000\025collectionEle\001\346\001\226\r\211\000\013-+\001\023\010t\0000\216\331\000\000L9E$;L\000\nmapKey\001@\rS\014\014map\005\227\035\024,\010metadatat\000\017)aXutil/Map;L\000\010nullablet\000\023\t\035%~\030Boolean!?\010row\t\343\010t\000$\212\243\000\001T!\374\030Namet\000-\2122\000\000$\001\254\001/\020;xr\000,nu\001\t\2109\3360\013PLl[\357\3103\002\000\000xp\001\001\014sr\000\036AC\000.\001\342\004.C5|Ds$EmptyMapY6\024\205Z\334\347\320\0053\014sr\000\021\005/\020lang.\r\3648\315 r\200\325\234\372\356\002\000\001Z\000\005v!\344\034xp\000p~r\000+\212\234\000\021\314\000\000\r\001\000\022e1\000\016\031f\014Enum\r\034\005\035(pt\000\006STRINGs!\304\020\007pppp\001\t\000\020\001\005\010\022p~\001\007@\023t\000\007BOOLEANt\000\003BIT"
#     representation {
#       atomic_type: BOOLEAN
#     }
#     argument_type {
#       atomic_type: STRING
#     }
#     argument {
#       atomic_value {
#         string: ""
#       }
#     }
#   }
# }
# id: 8
# encoding_position: 8
